# %%
from pathlib import Path
import tempfile

from bionemo.testing.data.load import load

# %%
# xfail -- we need to file a bug or figure out how to call the ngcsdk from a jupyter notebook
# NBVAL_RAISES_EXCEPTION
with tempfile.TemporaryDirectory() as cache_dir:
    load("esm2/testdata_esm2_pretrain:2.0", source="ngc", cache_dir=Path(cache_dir))
# Out:
# Downloading data from 'nvidia/clara/esm2_pretrain_nemo2_testdata:1.0' to file '/tmp/tmpglnde0ml/dc23f4aaad387ecc12e53d56b8176430-esm2_pretrain_nemo2_testdata:1.0'.
# Getting files to download...
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[2], line 4
#       1 # xfail -- we need to file a bug or figure out how to call the ngcsdk from a jupyter notebook
#       2 # NBVAL_RAISES_EXCEPTION
#       3 with tempfile.TemporaryDirectory() as cache_dir:
# ----> 4     load("esm2/testdata_esm2_pretrain:2.0", source="ngc", cache_dir=Path(cache_dir))
#
# File /workspaces/bionemo-framework/sub-packages/bionemo-testing/src/bionemo/testing/data/load.py:158, in load(model_or_data_tag, source, resources, cache_dir)
#     155 else:
#     156     raise ValueError(f"Source '{source}' not supported.")
# --> 158 download = pooch.retrieve(
#     159     url=str(url),
#     160     known_hash=resource.sha256,
#     161     path=cache_dir,
#     162     downloader=download_fn,
#     163     processor=processor,
#     164 )
#     166 # Pooch by default returns a list of unpacked files if they unpack a zipped or tarred directory. Instead of that, we
#     167 # just want the unpacked, parent folder.
#     168 if isinstance(download, list):
#
# File /usr/local/lib/python3.10/dist-packages/pooch/core.py:239, in retrieve(url, known_hash, fname, path, processor, downloader, progressbar)
#     236 if downloader is None:
#     237     downloader = choose_downloader(url, progressbar=progressbar)
# --> 239 stream_download(url, full_path, known_hash, downloader, pooch=None)
#     241 if known_hash is None:
#     242     get_logger().info(
#     243         "SHA256 hash of downloaded file: %s\n"
#     244         "Use this value as the 'known_hash' argument of 'pooch.retrieve'"
#    (...)
#     247         file_hash(str(full_path)),
#     248     )
#
# File /usr/local/lib/python3.10/dist-packages/pooch/core.py:807, in stream_download(url, fname, known_hash, downloader, pooch, retry_if_failed)
#     803 try:
#     804     # Stream the file to a temporary so that we can safely check its
#     805     # hash before overwriting the original.
#     806     with temporary_file(path=str(fname.parent)) as tmp:
# --> 807         downloader(url, tmp, pooch)
#     808         hash_matches(tmp, known_hash, strict=True, source=str(fname.name))
#     809         shutil.move(tmp, str(fname))
#
# File /workspaces/bionemo-framework/sub-packages/bionemo-testing/src/bionemo/testing/data/load.py:98, in NGCDownloader.__call__(self, url, output_file, _)
#      95 ngc_dirname = Path(url).name.replace(":", "_v")
#      97 with tempfile.TemporaryDirectory(dir=output_file.parent) as temp_dir:
# ---> 98     download_fns[self.ngc_registry](url, temp_dir, file_patterns=[self.filename])
#      99     shutil.move(Path(temp_dir) / ngc_dirname / self.filename, output_file)
#
# File /usr/local/lib/python3.10/dist-packages/ngcbpc/util/utils.py:540, in extra_args.<locals>.wrapper(*args, **kwargs)
#     538         del kwargs["debug"]
#     539         warnings.warn("The 'debug' argument is deprecated and will be removed soon.", DeprecationWarning)
# --> 540 retval = func(*args, **kwargs)
#     541 return retval
#
# File /usr/local/lib/python3.10/dist-packages/registry/api/resources.py:143, in ResourceAPI.download_version(self, target, destination, file_patterns, exclude_patterns)
#     140 except ResourceNotFoundException:
#     141     raise ResourceNotFoundException(f"'{target}' could not be found.") from None
# --> 143 self._download(mrt, download_dir, file_patterns=file_patterns, exclude_patterns=exclude_patterns)
#
# File /usr/local/lib/python3.10/dist-packages/registry/api/resources.py:999, in ResourceAPI._download(self, mrt, download_dir, file_patterns, exclude_patterns)
#     990 download_dir = f"{download_dir}/{mrt.name}_v{mrt.version}"
#     991 started_at = datetime.datetime.now()
#     992 (
#     993     elapsed,
#     994     download_count,
#     995     download_size,
#     996     failed_count,
#     997     _,
#     998     _,
# --> 999 ) = async_download.direct_download_files(
#    1000     "resource",
#    1001     mrt.name,
#    1002     mrt.org,
#    1003     mrt.team,
#    1004     mrt.version,
#    1005     url,
#    1006     paginated,
#    1007     dl_files_with_size,
#    1008     total_size,
#    1009     download_dir,
#    1010 )
#    1011 ended_at = datetime.datetime.now()
#    1012 status = "FAILED" if failed_count else "COMPLETED"
#
# File /usr/local/lib/python3.10/dist-packages/ngcbpc/transfer/async_download.py:932, in direct_download_files(dl_type, name, org, team, version, url, paginated, dl_files_with_size, size, download_dir)
#     930 time_started = time.monotonic()
#     931 try:
# --> 932     asyncio.run(
#     933         _direct_download_files(
#     934             dl_type,
#     935             name,
#     936             org,
#     937             team,
#     938             version,
#     939             url,
#     940             paginated,
#     941             download_dir,
#     942             auth_org=org,
#     943             auth_team=team,
#     944         )
#     945     )
#     946 except KeyboardInterrupt:
#     947     printer.print_ok("\nTerminating download...\n")
#
# File /usr/lib/python3.10/asyncio/runners.py:33, in run(main, debug)
#       9 """Execute the coroutine and return the result.
#      10
#      11 This function runs the passed coroutine, taking care of
#    (...)
#      30     asyncio.run(main())
#      31 """
#      32 if events._get_running_loop() is not None:
# ---> 33     raise RuntimeError(
#      34         "asyncio.run() cannot be called from a running event loop")
#      36 if not coroutines.iscoroutine(main):
#      37     raise ValueError("a coroutine was expected, got {!r}".format(main))
#
# RuntimeError: asyncio.run() cannot be called from a running event loop

# %%
with tempfile.TemporaryDirectory() as cache_dir:
    load("esm2/testdata_esm2_pretrain:2.0", source="pbss", cache_dir=Path(cache_dir))
# Out:
# Downloading data from 's3://general-purpose/esm2/pretrain/2024_03_sanity.tar.gz' to file '/tmp/tmpzm37lbjr/f796e1ca28311606ff7dd62a067508bf-2024_03_sanity.tar.gz'.
# s3://general-purpose/esm2/pretrain/2024_03_sanity.tar.gz: 100%|██████████| 73.3M/73.3M [00:03<00:00, 23.0MB/s]
# Untarring contents of '/tmp/tmpzm37lbjr/f796e1ca28311606ff7dd62a067508bf-2024_03_sanity.tar.gz' to '/tmp/tmpzm37lbjr/f796e1ca28311606ff7dd62a067508bf-2024_03_sanity.tar.gz.untar'
